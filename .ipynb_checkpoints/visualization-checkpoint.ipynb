# %% [markdown]
# # Visualization Catalog
#
# - [Map Crime Data to Geographic Data](#1)
# - [Map of City-Level Crime Numbers](#2)
# - [Word Cloud](#3)
#     - [NumberOnMap](NumberOnMap.html)
# - [Place Word Clouds on The Map](#4)
#     - [WordCloudOnMap](WordCloudOnMap.html)

# %% [markdown]
# <a id=1></a>
# ## Map Crime Data to Geographic Data

# %%
import geopandas as gpd
import pandas as pd
import re

# %%
# Load the shape file of the map of China
china_map = gpd.read_file('viz_materials/map/city.shp')

# Select the subset of the geographic data
china_map = china_map.iloc[:, [0, 4]]
china_map.columns = ["City_CN", "geometry"]

china_map.head()
# Out:
#      City_CN                                           geometry
# 0  阿坝藏族羌族自治州  POLYGON ((102.95840 34.27996, 102.95933 34.270...
# 1      阿克苏地区  POLYGON ((82.82279 42.64573, 82.82544 42.64289...
# 2       阿拉尔市  POLYGON ((81.86460 40.94205, 81.86914 40.94097...
# 3       阿拉善盟  POLYGON ((99.00000 42.60309, 99.50532 42.56749...
# 4      阿勒泰地区  POLYGON ((87.79720 49.18060, 87.81916 49.17268...

# %%
# Load the crime data
crime = pd.read_csv("data.csv", encoding="utf-8")

# Split the location into City and Province columns
crime.columns = ["Count", "City_CN", "Location"]
crime.loc[:, "City"] = crime.Location.apply(lambda x: re.findall(r"\w+", x)[0])
crime.loc[:, "Province"] = crime.Location.apply(lambda x: re.findall(r"\w+", x)[1])

# %%
# Check unusual splitting results of provinces
crime[crime.Province.apply(lambda x: len(x) < 5)]
# Out:
#      Count City_CN                 Location   City Province
# 26       1     延安市    ("Yan'an", 'Shaanxi')    Yan       an
# 40       1     普洱市      ("Pu'er", 'Yunnan')     Pu       er
# 145      4     广安市  ("Guang'an", 'Sichuan')  Guang       an
# 223      9     六安市       ("Lu'an", 'Anhui')     Lu       an
# 232     10     淮安市   ("Huai'an", 'Jiangsu')   Huai       an
# 259     30     西安市     ("Xi'an", 'Shaanxi')     Xi       an

# %%
# Check unusual splitting results of cities
crime[crime.City.apply(lambda x: len(x) < 5)]
# Out:
#      Count    City_CN                Location  City  Province
# 26       1        延安市   ("Yan'an", 'Shaanxi')   Yan        an
# 40       1        普洱市     ("Pu'er", 'Yunnan')    Pu        er
# 107      2  阿坝藏族羌族自治州      ('Aba', 'Sichuan')   Aba   Sichuan
# 123      3        淄博市    ('Zibo', 'Shandong')  Zibo  Shandong
# 126      3        菏泽市    ('Heze', 'Shandong')  Heze  Shandong
# 136      3       马鞍山市  ("Ma'anshan", 'Anhui')    Ma    anshan
# 173      5    大理白族自治州      ('Dali', 'Yunnan')  Dali    Yunnan
# 177      5        无锡市     ('Wuxi', 'Jiangsu')  Wuxi   Jiangsu
# 223      9        六安市      ("Lu'an", 'Anhui')    Lu        an
# 232     10        淮安市  ("Huai'an", 'Jiangsu')  Huai        an
# 244     16        芜湖市       ('Wuhu', 'Anhui')  Wuhu     Anhui
# 259     30        西安市    ("Xi'an", 'Shaanxi')    Xi        an

# %%
# Manually repair inaccurate splits
wrong_index = [26, 40, 136, 145, 223, 232, 259]
correct_location = [["Yan'an", "Shaanxi"],
                    ["Pu'er", "Yunnan"],
                    ["Ma'anshan", "Anhui"],
                    ["Guang'an", "Sichuan"],
                    ["Lu'an", "Anhui"],
                    ["Huai'an", "Jiangsu"],
                    ["Xi'an", "Shaanxi"]]

for n, i in enumerate(wrong_index):
    crime.loc[i, ["City", "Province"]] = correct_location[n]

# %%
# Drop the redundant column
crime.drop("Location", axis=1, inplace=True)
crime.head()
# Out:
#    Count City_CN       City      Province
# 0      1    七台河市    Qitaihe  Heilongjiang
# 1      1     三明市    Sanming        Fujian
# 2      1    三门峡市  Sanmenxia         Henan
# 3      1     东营市   Dongying      Shandong
# 4      1     临汾市     Linfen        Shanxi

# %%
# Merge the crime data with the geographic data using Chinese names of the cities
merged_df = pd.merge(china_map, crime, on="City_CN", how = "right")
merged_df.head()
# Out:
#   City_CN                                           geometry  Count  \
# 0    七台河市  POLYGON ((131.27322 46.32068, 131.27301 46.320...      1
# 1     三明市  POLYGON ((117.30633 27.11907, 117.31564 27.117...      1
# 2    三门峡市  POLYGON ((111.96644 35.07208, 111.96662 35.071...      1
# 3     东营市  MULTIPOLYGON (((119.22069 37.78119, 119.22052 ...      1
# 4     临汾市  POLYGON ((110.71945 36.91298, 110.73457 36.907...      1
#
#         City      Province
# 0    Qitaihe  Heilongjiang
# 1    Sanming        Fujian
# 2  Sanmenxia         Henan
# 3   Dongying      Shandong
# 4     Linfen        Shanxi

# %%
# Render geojson file
(merged_df.drop("City_CN", axis=1)
          .to_file("viz_materials/city_crime.geojson",
                   driver="GeoJSON",
                   encoding="utf-8"))

# %% [markdown]
# <a id=2></a>
# ## Map of City-Level Crime Numbers

# %% [markdown]
# Interact with [NumberOnMap](NumberOnMap.html) and more learn about the data.

# %%
from bokeh.io import show, output_file
from bokeh.models import GeoJSONDataSource, LinearColorMapper, HoverTool
from bokeh.palettes import Reds6 as palette
from bokeh.plotting import figure

# %%
# load geojson file rendered in the last part
with open("viz_materials/city_crime.geojson") as f:
    geo_source = GeoJSONDataSource(geojson=f.read())

# Set the appearance of the map
palette = tuple(reversed(palette))
color_mapper = LinearColorMapper(palette=palette)
TOOLS = "pan,wheel_zoom,reset,hover,save"

# Plot the map with the crime data
p = figure(title="Crime Case Counts",
           tools=TOOLS,
           x_axis_location=None, y_axis_location=None,
           width=600, height=600)

p.grid.grid_line_color = None

p.patches("xs", "ys",
          fill_alpha=0.7,
          fill_color={'field': 'Count',
                      'transform': color_mapper}, 
          line_color='white', line_width=0.5,
          source=geo_source)

# Set the hover of the map
hover = p.select_one(HoverTool)
hover.point_policy = "follow_mouse"
hover.tooltips = [
    ("City", "@City"),
    ("Count", "@Count"),
    ("(Lng, Lat)", "($x, $y)")
]

# Save the map to repository
output_file("NumberOnMap.html", title="Crime Case Counts")

# %% [markdown]
# <a id=3></a>
# ## Word Cloud

# %%
# %matplotlib inline
import jieba
import pandas as pd
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Load customized dictionary
jieba.load_userdict("viz_materials/word_dictionary.txt")
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\lenovo\AppData\Local\Temp\jieba.cache
# Loading model cost 1.453 seconds.
# Prefix dict has been built successfully.

# %%
# Load case data matched with cities
cases = pd.read_csv("matches.csv")

# Group by city and concatenate the cases
gb = cases.groupby("location").sum()

# Extract the top 10 cities with the most cases
crime_top10 = crime.sort_values("Count", ascending=False).head(10)
gb_top10 = pd.merge(
    gb, crime_top10,
    left_on=gb.index,
    right_on="City_CN",
    how="right"
)
gb_top10
# Out:
#                                                 case  Count City_CN  \
# 0  北京工业大学2001级工商管理系男学生郭某某杀害女友被判无期后减刑9次，出狱后拒戴口罩打死老...     88     北京市
# 1  江苏南京大学暑期支教女学生洗澡被偷拍，做案者仅罚款500元原北大教师沈阳被指“性侵女生致其自...     48     南京市
# 2  安徽巢湖烔炀镇白庙唐村一男子唐某根将妻子勒死家中，逃亡36年安徽合肥银马公寓一男子杀妻后跳楼...     44     合肥市
# 3  上海东华大学04级研究生章胜偷窥女生如厕上海财经大学副教授钱逢胜被曝性侵女学生上海海事大学解...     42     上海市
# 4  网曝华南理工大学公共管理学院副教授王雨磊性侵女学生网曝华南理工大学公共管理学院院长王郅强性侵...     40     广州市
# 5  四川美术学院副教授王小箭餐厅强抱吻女生被处分重庆渝中区龙湖时代天街鲁某当街连捅妻子数十刀重庆...     37     重庆市
# 6  浙大央美性搔扰惯犯崔青洲浙大学生努某某强奸被判一年半，学校不与开除，留校察看浙江杭州男子许国...     37     杭州市
# 7  陕西西北大学新闻传播学院讲师张晓性骚扰女生陕西西安莲湖区男子李某杀害妻子潜逃15年陕西西安东...     30     西安市
# 8  辽宁大连男子酒后杀母抛尸野外辽宁大连男子趁女友不在强奸女友11岁女儿致其怀孕流产 获刑13年...     27     大连市
# 9  江苏苏州男子王某因被妻子屏蔽朋友圈,持刀挟持妻子砍伤侄女江苏苏州高新区狮山新苑某栋3XX室一...     25     苏州市
#
#         City   Province
# 0    Beijing    Beijing
# 1    Nanjing    Jiangsu
# 2      Hefei      Anhui
# 3   Shanghai   Shanghai
# 4  Guangzhou  Guangdong
# 5  Chongqing  Chongqing
# 6   Hangzhou   Zhejiang
# 7      Xi'an    Shaanxi
# 8     Dalian   Liaoning
# 9     Suzhou    Jiangsu

# %%
# Define set of singe-word verbs, preventing possibly useful words from being filtered out
S_single = ["女", "诱", "打", "脱", "怼", "杀", "捅", "刺", "刀", "锤", "死", "跳", "伤", "摸", "砖",
            "蹭", "骗", "扔", "掐", "骗", "砍", "赔", "跑", "胸", "拘", "追", "抛", "扇", "打", "怒",
            "剁", "抱", "摸", "弃", "拽", "腰", "拍", "藏", "手", "尸", "戳", "弑", "腿", "家", "村",
            "逼", "灌", "哭", "臀", "闯", "划", "脸", "摔", "吓", "断", "捂", "娶", "拍", "镇", "狠",
            "抡", "拒", "掳", "偷", "钱", "揍", "车", "藏", "拉", "勒", "泼", "踹", "头", "颈", "勒",
            "鼻", "车", "牢", "扒", "泼", "电", "掌", "掴", "砸", "暴", "塞", "母", "烧", "趁", "剐",
            "吻", "背", "卖", "玩", "逃", "摔", "旅", "浇", "抡", "爬", "妻", "河", "摔", "持", "球",
            "楼", "美", "性", "孝", "喜", "险", "男", "骑", "挑", "戴", "裤", "血", "救", "病", "亲",
            "欠", "聊", "挠", "露"]

# Define worthless vocabularies
S_conj = ["某某", "王某", "李某"]

# Define a function to process the descriptions of the cases in to
# string for generating word clouds
def text_processor(text):
    '''
    Split the given text into meaningful Chinese vocabularies.

    Input:
     text(string): given text

    Output:
     string: meaningful words seperated by space
    '''
    text = re.sub(r"[\W\d]", "", text)
    lst = []
    for word in jieba.cut(text):
        if (word not in S_conj) and \
           ((len(word) > 1) or (word in S_single)):
            lst.append(word)
    return " ".join(lst)

# Apply the fuction to the dataframe
word_df = pd.DataFrame(gb_top10.case
                               .apply(lambda x: text_processor(x)))
word_df
# Out:
#                                                 case
# 0  北京工业大学 工商 管理系 男 学生 杀害 女友 被判 无期 减刑 出狱 拒 戴 口罩 打死...
# 1  江苏 南京大学 暑期 支教 女学生 洗澡 偷拍 做案 罚款 元原 北大 教师 沈阳 性侵 女...
# 2  安徽 巢湖 炀镇 白庙 唐村 男子 某根 妻子 勒死 家中 逃亡 安徽 合肥 银马 公寓 男...
# 3  上海 东华大学 研究生 章胜 偷窥女生 如厕 上海财经大学 副教授 钱逢胜 性侵 女学生 上...
# 4  华南理工大学 公共 管理 学院 副教授 王雨磊 性侵 女学生 华南理工大学 公共 管理 学院...
# 5  四川 美术学院 副教授 王小箭 餐厅 强抱 吻 女生 处分 重庆 渝中区 龙湖 时代 天街 ...
# 6  浙大 央美性 搔扰 惯犯 青洲 大学生 强奸 被判 一年 学校 开除 留校察看 浙江 杭州 ...
# 7  陕西 西北大学 新闻 传播学院 讲师 张晓 性骚扰 女生 陕西 西安 莲湖区 男子 杀害 妻...
# 8  辽宁大连 男子 酒后 杀母 抛尸 野外 辽宁大连 男子 趁 女友 强奸 女友 女儿 致其 怀...
# 9  江苏 苏州 男子 妻子 屏蔽 朋友圈 持刀 挟持 妻子 砍伤 侄女 江苏 苏州高新区 狮山 ...

# %%
# Generate word clouds for the Top10 cities
for i in range(10):
    # Plot word cloud per city
    s = word_df.iloc[i, 0]
    word_cloud = WordCloud(
        collocations=False,
        background_color="white",
        max_words=30,
        font_path="viz_materials/Deng.ttf"
    ).generate(s)

    plt.imshow(word_cloud, interpolation="bilinear")
    plt.axis("off")

    # Save the plots to the repository
    plt.savefig("viz_materials/word_clouds/{}.png".format(i),
                format="png",
                dpi=50)

# %%
# Plot word cloud for all the key words in the dataframe
total_str = word_df.case.sum()

total_wc = WordCloud(
        collocations=False,
        background_color="white",
        max_words=50,
        font_path="viz_materials/Deng.ttf"
).generate(total_str)

plt.imshow(total_wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# <a id=4></a>
# ## Place Word Clouds on The Map

# %% [markdown]
# Interact with [WordCloudOnMap](WordCloudOnMap.html) and learn more about the data.

# %%
import pandas as pd
import folium
import base64

# %%
# Load longitude & latitude data of cities
city_lat_lng = pd.read_csv("viz_materials/city_lat_lng.csv")

# Select the subset of the data
city_lat_lng = city_lat_lng.loc[:, ["city", "lat", "lng"]]
city_lat_lng.columns = ["City", "lat", "lng"]

city_lat_lng.head()
# Out:
#         City      lat       lng
# 0   Shanghai  31.1667  121.4667
# 1  Guangzhou  23.1288  113.2590
# 2    Beijing  39.9050  116.3914
# 3   Shenzhen  22.5350  114.0540
# 4    Nanyang  32.9987  112.5292

# %%
# Manually preprocess the data set to match with the gb_top10 dataframe
city_lat_lng.iloc[31, 0] = "Xi'an"
city_lat_lng.drop(60, inplace=True)

# Merge the two dataframes
top10_lat_lng = (pd.merge(city_lat_lng, gb_top10, on="City", how="inner")
                   .sort_values("Count", ascending=False))
top10_lat_lng
# Out:
#         City      lat       lng  \
# 2    Beijing  39.9050  116.3914
# 4    Nanjing  32.0500  118.7667
# 5      Hefei  31.8639  117.2808
# 0   Shanghai  31.1667  121.4667
# 1  Guangzhou  23.1288  113.2590
# 3  Chongqing  29.5500  106.5069
# 7   Hangzhou  30.2500  120.1675
# 6      Xi'an  34.2667  108.9000
# 9     Dalian  38.9131  121.6100
# 8     Suzhou  31.3040  120.6164
#
#                                                 case  Count City_CN   Province
# 2  北京工业大学2001级工商管理系男学生郭某某杀害女友被判无期后减刑9次，出狱后拒戴口罩打死老...     88     北京市    Beijing
# 4  江苏南京大学暑期支教女学生洗澡被偷拍，做案者仅罚款500元原北大教师沈阳被指“性侵女生致其自...     48     南京市    Jiangsu
# 5  安徽巢湖烔炀镇白庙唐村一男子唐某根将妻子勒死家中，逃亡36年安徽合肥银马公寓一男子杀妻后跳楼...     44     合肥市      Anhui
# 0  上海东华大学04级研究生章胜偷窥女生如厕上海财经大学副教授钱逢胜被曝性侵女学生上海海事大学解...     42     上海市   Shanghai
# 1  网曝华南理工大学公共管理学院副教授王雨磊性侵女学生网曝华南理工大学公共管理学院院长王郅强性侵...     40     广州市  Guangdong
# 3  四川美术学院副教授王小箭餐厅强抱吻女生被处分重庆渝中区龙湖时代天街鲁某当街连捅妻子数十刀重庆...     37     重庆市  Chongqing
# 7  浙大央美性搔扰惯犯崔青洲浙大学生努某某强奸被判一年半，学校不与开除，留校察看浙江杭州男子许国...     37     杭州市   Zhejiang
# 6  陕西西北大学新闻传播学院讲师张晓性骚扰女生陕西西安莲湖区男子李某杀害妻子潜逃15年陕西西安东...     30     西安市    Shaanxi
# 9  辽宁大连男子酒后杀母抛尸野外辽宁大连男子趁女友不在强奸女友11岁女儿致其怀孕流产 获刑13年...     27     大连市   Liaoning
# 8  江苏苏州男子王某因被妻子屏蔽朋友圈,持刀挟持妻子砍伤侄女江苏苏州高新区狮山新苑某栋3XX室一...     25     苏州市    Jiangsu

# %%
# Plot the crime map
M = folium.Map(location=[37, 105], zoom_start=4)

folium.Choropleth(
    geo_data="viz_materials/city_crime.geojson",
    data=merged_df,
    columns=["City", "Count"],
    key_on="feature.properties.City",
    fill_color="OrRd",
    fill_opacity=0.8,
    line_opacity=0.5,
    legend_name="Count",
    name="crime number",
    nan_fill_color="Gray",
    nan_fill_opacity=0.2,
).add_to(M)

# Add markers on the map displaying the word clouds of the top10 cities
top10_markers = folium.FeatureGroup(name="wordclouds of top10 cities")
for i in range(10):
    city, lat, lng = top10_lat_lng.iloc[i, [0, 1, 2]]

    # Load corresponding word cloud of the city
    png = "viz_materials/word_clouds/{}.png".format(i)
    encoded = base64.b64encode(open(png, "rb").read())

    html = '<img src="data:image/png;base64,{}">'.format
    iframe = folium.IFrame(html(encoded.decode()), width=320, height=220)

    # Create marker
    marker = folium.Marker(
        location=[lat, lng],
        popup=folium.Popup(iframe, max_width=600),
        icon=folium.Icon(color="red", icon="info-sign"),
    )

    top10_markers.add_children(marker)

# Add markers as a layer
M.add_children(top10_markers)

M.add_children(folium.LayerControl())

# Save the map to repository
M.save("WordCloudOnMap.html")

# %% [markdown]
# ## Statistic Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Descriptive statistics
df = pd.read_csv("total_data_impute.csv", encoding="utf-8").set_index("Unnamed: 0")

df.describe().transpose()
# Out:
#                                                     count          mean  \
# number of cases                                     270.0  6.040741e+00
# Population at Year-end (10000 persons)              268.0  4.934265e+02
# Natural growth rate (‰)                             268.0  6.431380e+00
# Number of employees at the end of the year (10,...  268.0  6.907171e+01
# Number of the registered unemployed at the end ...  268.0  3.019150e+04
# Average annual salary per urban employee ( Yuan)    268.0  6.038496e+04
# Number of average employees on site (10,000 Yuan)   268.0  6.105782e+01
# Population density (person / square kilometer)      268.0  4.630512e+02
# Per Capita GDP(yuan)                                268.0  5.578427e+04
# Secondary industry as percentage to GDP             268.0  4.555111e+01
# Service Sector as Percentage to GRP                 268.0  4.307955e+01
# Total retail sales of social consumer goods (10...  268.0  1.255311e+07
# Government expenditure on Science (10,000 yuan)     268.0  1.260453e+05
# Government expenditure on Education (10,000 yuan)   268.0  8.213915e+05
# Number of secondary schools                         268.0  2.298060e+02
# Number of theaters                                  268.0  1.683592e+01
# Collections of public libraries (100 people)        268.0  6.233266e+01
# Number of employees joining urban basic medical...  268.0  1.282882e+06
# Persons covered of unemployment insurance           268.0  6.475491e+05
# Population (registered residence population) at...  268.0  4.870269e+02
# Number of male population (registered residence...  191.0  2.237528e+02
# Number of female population (registered residen...  202.0  2.256166e+02
#
#                                                              std  \
# number of cases                                     9.190781e+00
# Population at Year-end (10000 persons)              2.991836e+02
# Natural growth rate (‰)                             4.759376e+00
# Number of employees at the end of the year (10,...  8.595236e+01
# Number of the registered unemployed at the end ...  3.054847e+04
# Average annual salary per urban employee ( Yuan)    1.040837e+04
# Number of average employees on site (10,000 Yuan)   7.224031e+01
# Population density (person / square kilometer)      3.068487e+02
# Per Capita GDP(yuan)                                2.824536e+04
# Secondary industry as percentage to GDP             8.037923e+00
# Service Sector as Percentage to GRP                 7.977722e+00
# Total retail sales of social consumer goods (10...  1.376889e+07
# Government expenditure on Science (10,000 yuan)     3.170132e+05
# Government expenditure on Education (10,000 yuan)   8.852793e+05
# Number of secondary schools                         1.224501e+02
# Number of theaters                                  1.925107e+01
# Collections of public libraries (100 people)        6.609603e+01
# Number of employees joining urban basic medical...  1.798448e+06
# Persons covered of unemployment insurance           1.060662e+06
# Population (registered residence population) at...  2.985366e+02
# Number of male population (registered residence...  1.225685e+02
# Number of female population (registered residen...  1.526139e+02
#
#                                                              min  \
# number of cases                                          0.00000
# Population at Year-end (10000 persons)                  58.87600
# Natural growth rate (‰)                                 -5.61600
# Number of employees at the end of the year (10,...       6.78160
# Number of the registered unemployed at the end ...    2964.60000
# Average annual salary per urban employee ( Yuan)     36261.09400
# Number of average employees on site (10,000 Yuan)        6.05200
# Population density (person / square kilometer)          10.38500
# Per Capita GDP(yuan)                                 16570.60000
# Secondary industry as percentage to GDP                 15.49000
# Service Sector as Percentage to GRP                     27.26750
# Total retail sales of social consumer goods (10...  651016.20000
# Government expenditure on Science (10,000 yuan)       1811.60000
# Government expenditure on Education (10,000 yuan)    80321.80000
# Number of secondary schools                             38.60000
# Number of theaters                                       1.00000
# Collections of public libraries (100 people)             5.82500
# Number of employees joining urban basic medical...   94531.20000
# Persons covered of unemployment insurance            47605.20000
# Population (registered residence population) at...      59.01306
# Number of male population (registered residence...      30.06768
# Number of female population (registered residen...      28.98312
#
#                                                              25%  \
# number of cases                                     1.000000e+00
# Population at Year-end (10000 persons)              2.969830e+02
# Natural growth rate (‰)                             3.504308e+00
# Number of employees at the end of the year (10,...  2.941914e+01
# Number of the registered unemployed at the end ...  1.596888e+04
# Average annual salary per urban employee ( Yuan)    5.419938e+04
# Number of average employees on site (10,000 Yuan)   2.609950e+01
# Population density (person / square kilometer)      2.572467e+02
# Per Capita GDP(yuan)                                3.650060e+04
# Secondary industry as percentage to GDP             4.237438e+01
# Service Sector as Percentage to GRP                 3.801902e+01
# Total retail sales of social consumer goods (10...  5.063863e+06
# Government expenditure on Science (10,000 yuan)     2.560757e+04
# Government expenditure on Education (10,000 yuan)   4.711163e+05
# Number of secondary schools                         1.540000e+02
# Number of theaters                                  8.000000e+00
# Collections of public libraries (100 people)        2.661922e+01
# Number of employees joining urban basic medical...  5.280608e+05
# Persons covered of unemployment insurance           2.299245e+05
# Population (registered residence population) at...  2.968760e+02
# Number of male population (registered residence...  1.384080e+02
# Number of female population (registered residen...  1.362430e+02
#
#                                                              50%  \
# number of cases                                     3.000000e+00
# Population at Year-end (10000 persons)              4.695526e+02
# Natural growth rate (‰)                             6.451838e+00
# Number of employees at the end of the year (10,...  4.746652e+01
# Number of the registered unemployed at the end ...  2.479285e+04
# Average annual salary per urban employee ( Yuan)    5.794215e+04
# Number of average employees on site (10,000 Yuan)   4.243400e+01
# Population density (person / square kilometer)      3.911200e+02
# Per Capita GDP(yuan)                                4.770829e+04
# Secondary industry as percentage to GDP             4.646013e+01
# Service Sector as Percentage to GRP                 4.167000e+01
# Total retail sales of social consumer goods (10...  8.576831e+06
# Government expenditure on Science (10,000 yuan)     5.233995e+04
# Government expenditure on Education (10,000 yuan)   6.751831e+05
# Number of secondary schools                         2.144753e+02
# Number of theaters                                  1.266847e+01
# Collections of public libraries (100 people)        4.102304e+01
# Number of employees joining urban basic medical...  8.449851e+05
# Persons covered of unemployment insurance           3.926014e+05
# Population (registered residence population) at...  4.524320e+02
# Number of male population (registered residence...  2.049440e+02
# Number of female population (registered residen...  2.050699e+02
#
#                                                              75%           max
# number of cases                                     6.000000e+00  8.900000e+01
# Population at Year-end (10000 persons)              6.080080e+02  3.386608e+03
# Natural growth rate (‰)                             9.700500e+00  1.685400e+01
# Number of employees at the end of the year (10,...  7.541499e+01  7.913771e+02
# Number of the registered unemployed at the end ...  3.253763e+04  2.461742e+05
# Average annual salary per urban employee ( Yuan)    6.560944e+04  1.248119e+05
# Number of average employees on site (10,000 Yuan)   6.973741e+01  7.375500e+02
# Population density (person / square kilometer)      6.502675e+02  2.574625e+03
# Per Capita GDP(yuan)                                6.581025e+04  2.010722e+05
# Secondary industry as percentage to GDP             5.054500e+01  6.936000e+01
# Service Sector as Percentage to GRP                 4.707365e+01  7.970250e+01
# Total retail sales of social consumer goods (10...  1.424614e+07  1.097611e+08
# Government expenditure on Science (10,000 yuan)     9.692745e+04  3.384231e+06
# Government expenditure on Education (10,000 yuan)   9.727978e+05  8.950368e+06
# Number of secondary schools                         2.877143e+02  1.141200e+03
# Number of theaters                                  2.131148e+01  2.510000e+02
# Collections of public libraries (100 people)        7.564750e+01  5.203450e+02
# Number of employees joining urban basic medical...  1.257960e+06  1.559115e+07
# Persons covered of unemployment insurance           5.835397e+05  1.133703e+07
# Population (registered residence population) at...  6.084410e+02  3.386500e+03
# Number of male population (registered residence...  2.845689e+02  6.743815e+02
# Number of female population (registered residen...  2.889289e+02  1.645000e+03

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Number of male population (registered residence population) at the end of the year (10,000)      79
# Number of female population (registered residence population) at the end of the year (10,000)    68
# Service Sector as Percentage to GRP                                                               2
# Secondary industry as percentage to GDP                                                           2
# Number of employees joining urban basic medical care system                                       2
# Collections of public libraries (100 people)                                                      2
# Number of theaters                                                                                2
# Number of secondary schools                                                                       2
# Government expenditure on Education (10,000 yuan)                                                 2
# Government expenditure on Science (10,000 yuan)                                                   2
# Total retail sales of social consumer goods (10,000 Yuan)                                         2
# Per Capita GDP(yuan)                                                                              2
# Population (registered residence population) at the end of the year (10,000)                      2
# Population density (person / square kilometer)                                                    2
# Number of average employees on site (10,000 Yuan)                                                 2
# Average annual salary per urban employee ( Yuan)                                                  2
# Number of the registered unemployed at the end of year                                            2
# Number of employees at the end of the year (10,000 Yuan)                                          2
# Natural growth rate (‰)                                                                           2
# Population at Year-end (10000 persons)                                                            2
# Persons covered of unemployment insurance                                                         2
# number of cases                                                                                   0
# City                                                                                              0
# location_ENG                                                                                      0
# province                                                                                          0
# dtype: int64

# %%
from sklearn.decomposition import PCA
from sklearn import preprocessing

from mpl_toolkits.mplot3d import Axes3D
from scipy import stats

# %%
df.head()
# Out:
#             number of cases  City                 location_ENG  \
# Unnamed: 0
# 0                         0   临沧市        ('Lincang', 'Yunnan')
# 1                         0   乌海市  ('Wuhai', 'Inner Mongolia')
# 2                         1  七台河市  ('Qitaihe', 'Heilongjiang')
# 3                         1   三明市        ('Sanming', 'Fujian')
# 4                         1  三门峡市       ('Sanmenxia', 'Henan')
#
#             Population at Year-end (10000 persons)  Natural growth rate (‰)  \
# Unnamed: 0
# 0                                       608.008000                 9.540000
# 1                                       262.801714                 3.688571
# 2                                        81.662000                -2.048000
# 3                                       286.424000                13.562000
# 4                                       718.879600                 7.924267
#
#             Number of employees at the end of the year (10,000 Yuan)  \
# Unnamed: 0
# 0                                                   67.622800
# 1                                                   31.986631
# 2                                                   10.089300
# 3                                                   24.403080
# 4                                                   67.714143
#
#             Number of the registered unemployed at the end of year  \
# Unnamed: 0
# 0                                                31644.066667
# 1                                                28642.000000
# 2                                                 8840.800000
# 3                                                10091.200000
# 4                                                28008.213333
#
#             Average annual salary per urban employee ( Yuan)  \
# Unnamed: 0
# 0                                               62658.793333
# 1                                               61967.695714
# 2                                               48290.960000
# 3                                               65480.386000
# 4                                               49751.920933
#
#             Number of average employees on site (10,000 Yuan)  \
# Unnamed: 0
# 0                                                   58.364833
# 1                                                   31.212000
# 2                                                    9.762000
# 3                                                   21.344000
# 4                                                   61.795200
#
#             Population density (person / square kilometer)  ...  \
# Unnamed: 0                                                  ...
# 0                                               257.246667  ...
# 1                                                53.709286  ...
# 2                                               137.615000  ...
# 3                                               123.670000  ...
# 4                                               760.757000  ...
#
#             Government expenditure on Education (10,000 yuan)  \
# Unnamed: 0
# 0                                               972797.800000
# 1                                               522155.057143
# 2                                                83776.800000
# 3                                               520682.800000
# 4                                               766183.826667
#
#             Number of secondary schools  Number of theaters  \
# Unnamed: 0
# 0                            259.000000           23.000000
# 1                            106.142857           14.142857
# 2                             45.000000            3.000000
# 3                            156.400000           20.000000
# 4                            340.506667           10.266667
#
#             Collections of public libraries (100 people)  \
# Unnamed: 0
# 0                                              30.530000
# 1                                              72.278571
# 2                                              27.700000
# 3                                             169.860000
# 4                                              25.260333
#
#             Number of employees joining urban basic medical care system  \
# Unnamed: 0
# 0                                               984350.866667
# 1                                               606709.714286
# 2                                               208099.200000
# 3                                               472247.000000
# 4                                               796378.386667
#
#             Persons covered of unemployment insurance  \
# Unnamed: 0
# 0                                       452032.800000
# 1                                       279168.514286
# 2                                        99408.000000
# 3                                       293083.400000
# 4                                       487342.866667
#
#             Population (registered residence population) at the end of the year (10,000)  \
# Unnamed: 0
# 0                                                  421.667714
# 1                                                  262.895000
# 2                                                   81.522000
# 3                                                  286.432000
# 4                                                  716.382833
#
#             Number of male population (registered residence population) at the end of the year (10,000)  \
# Unnamed: 0
# 0                                                  218.546626
# 1                                                  145.182474
# 2                                                   41.584000
# 3                                                  149.690000
# 4                                                         NaN
#
#             Number of female population (registered residence population) at the end of the year (10,000)  \
# Unnamed: 0
# 0                                                  203.119057
# 1                                                  135.336669
# 2                                                   39.971780
# 3                                                  136.570000
# 4                                                         NaN
#
#                   province
# Unnamed: 0
# 0                   Yunnan
# 1           Inner Mongolia
# 2             Heilongjiang
# 3                   Fujian
# 4                    Henan
#
# [5 rows x 25 columns]

# %%
df.iloc[:, 3:-1].corr()
# Out:
#                                                     Population at Year-end (10000 persons)  \
# Population at Year-end (10000 persons)                                            1.000000
# Natural growth rate (‰)                                                           0.125671
# Number of employees at the end of the year (10,...                                0.665268
# Number of the registered unemployed at the end ...                                0.562610
# Average annual salary per urban employee ( Yuan)                                  0.182487
# Number of average employees on site (10,000 Yuan)                                 0.585668
# Population density (person / square kilometer)                                    0.389202
# Per Capita GDP(yuan)                                                             -0.003051
# Secondary industry as percentage to GDP                                          -0.034553
# Service Sector as Percentage to GRP                                               0.108986
# Total retail sales of social consumer goods (10...                                0.643639
# Government expenditure on Science (10,000 yuan)                                   0.393479
# Government expenditure on Education (10,000 yuan)                                 0.691046
# Number of secondary schools                                                       0.925888
# Number of theaters                                                                0.333668
# Collections of public libraries (100 people)                                      0.100106
# Number of employees joining urban basic medical...                                0.589624
# Persons covered of unemployment insurance                                         0.499847
# Population (registered residence population) at...                                0.995504
# Number of male population (registered residence...                                0.987769
# Number of female population (registered residen...                                0.991756
#
#                                                     Natural growth rate (‰)  \
# Population at Year-end (10000 persons)                             0.125671
# Natural growth rate (‰)                                            1.000000
# Number of employees at the end of the year (10,...                -0.054519
# Number of the registered unemployed at the end ...                -0.155714
# Average annual salary per urban employee ( Yuan)                   0.008555
# Number of average employees on site (10,000 Yuan)                 -0.050368
# Population density (person / square kilometer)                     0.175029
# Per Capita GDP(yuan)                                              -0.089131
# Secondary industry as percentage to GDP                            0.101832
# Service Sector as Percentage to GRP                               -0.018209
# Total retail sales of social consumer goods (10...                -0.074223
# Government expenditure on Science (10,000 yuan)                   -0.083202
# Government expenditure on Education (10,000 yuan)                 -0.005596
# Number of secondary schools                                        0.105335
# Number of theaters                                                -0.059590
# Collections of public libraries (100 people)                      -0.045796
# Number of employees joining urban basic medical...                -0.112778
# Persons covered of unemployment insurance                         -0.070395
# Population (registered residence population) at...                 0.110815
# Number of male population (registered residence...                 0.203345
# Number of female population (registered residen...                 0.083318
#
#                                                     Number of employees at the end of the year (10,000 Yuan)  \
# Population at Year-end (10000 persons)                                                       0.665268
# Natural growth rate (‰)                                                                     -0.054519
# Number of employees at the end of the year (10,...                                           1.000000
# Number of the registered unemployed at the end ...                                           0.702338
# Average annual salary per urban employee ( Yuan)                                             0.616140
# Number of average employees on site (10,000 Yuan)                                            0.967640
# Population density (person / square kilometer)                                               0.444348
# Per Capita GDP(yuan)                                                                         0.441006
# Secondary industry as percentage to GDP                                                     -0.141037
# Service Sector as Percentage to GRP                                                          0.462858
# Total retail sales of social consumer goods (10...                                           0.928710
# Government expenditure on Science (10,000 yuan)                                              0.852956
# Government expenditure on Education (10,000 yuan)                                            0.933627
# Number of secondary schools                                                                  0.665810
# Number of theaters                                                                           0.673397
# Collections of public libraries (100 people)                                                 0.642923
# Number of employees joining urban basic medical...                                           0.933823
# Persons covered of unemployment insurance                                                    0.946259
# Population (registered residence population) at...                                           0.669269
# Number of male population (registered residence...                                           0.565574
# Number of female population (registered residen...                                           0.716288
#
#                                                     Number of the registered unemployed at the end of year  \
# Population at Year-end (10000 persons)                                                       0.562610
# Natural growth rate (‰)                                                                     -0.155714
# Number of employees at the end of the year (10,...                                           0.702338
# Number of the registered unemployed at the end ...                                           1.000000
# Average annual salary per urban employee ( Yuan)                                             0.451748
# Number of average employees on site (10,000 Yuan)                                            0.676979
# Population density (person / square kilometer)                                               0.329139
# Per Capita GDP(yuan)                                                                         0.338773
# Secondary industry as percentage to GDP                                                     -0.105810
# Service Sector as Percentage to GRP                                                          0.342014
# Total retail sales of social consumer goods (10...                                           0.764070
# Government expenditure on Science (10,000 yuan)                                              0.627196
# Government expenditure on Education (10,000 yuan)                                            0.702179
# Number of secondary schools                                                                  0.603625
# Number of theaters                                                                           0.405189
# Collections of public libraries (100 people)                                                 0.414871
# Number of employees joining urban basic medical...                                           0.708512
# Persons covered of unemployment insurance                                                    0.637713
# Population (registered residence population) at...                                           0.565435
# Number of male population (registered residence...                                           0.501138
# Number of female population (registered residen...                                           0.560281
#
#                                                     Average annual salary per urban employee ( Yuan)  \
# Population at Year-end (10000 persons)                                                      0.182487
# Natural growth rate (‰)                                                                     0.008555
# Number of employees at the end of the year (10,...                                          0.616140
# Number of the registered unemployed at the end ...                                          0.451748
# Average annual salary per urban employee ( Yuan)                                            1.000000
# Number of average employees on site (10,000 Yuan)                                           0.649732
# Population density (person / square kilometer)                                              0.214564
# Per Capita GDP(yuan)                                                                        0.635403
# Secondary industry as percentage to GDP                                                    -0.111315
# Service Sector as Percentage to GRP                                                         0.559988
# Total retail sales of social consumer goods (10...                                          0.651683
# Government expenditure on Science (10,000 yuan)                                             0.678109
# Government expenditure on Education (10,000 yuan)                                           0.647610
# Number of secondary schools                                                                 0.213495
# Number of theaters                                                                          0.541988
# Collections of public libraries (100 people)                                                0.679617
# Number of employees joining urban basic medical...                                          0.641831
# Persons covered of unemployment insurance                                                   0.680536
# Population (registered residence population) at...                                          0.179959
# Number of male population (registered residence...                                          0.224353
# Number of female population (registered residen...                                          0.260412
#
#                                                     Number of average employees on site (10,000 Yuan)  \
# Population at Year-end (10000 persons)                                                       0.585668
# Natural growth rate (‰)                                                                     -0.050368
# Number of employees at the end of the year (10,...                                           0.967640
# Number of the registered unemployed at the end ...                                           0.676979
# Average annual salary per urban employee ( Yuan)                                             0.649732
# Number of average employees on site (10,000 Yuan)                                            1.000000
# Population density (person / square kilometer)                                               0.469755
# Per Capita GDP(yuan)                                                                         0.487550
# Secondary industry as percentage to GDP                                                     -0.148353
# Service Sector as Percentage to GRP                                                          0.497597
# Total retail sales of social consumer goods (10...                                           0.946788
# Government expenditure on Science (10,000 yuan)                                              0.918524
# Government expenditure on Education (10,000 yuan)                                            0.949495
# Number of secondary schools                                                                  0.612800
# Number of theaters                                                                           0.756170
# Collections of public libraries (100 people)                                                 0.705856
# Number of employees joining urban basic medical...                                           0.939653
# Persons covered of unemployment insurance                                                    0.976690
# Population (registered residence population) at...                                           0.589766
# Number of male population (registered residence...                                           0.526562
# Number of female population (registered residen...                                           0.624974
#
#                                                     Population density (person / square kilometer)  \
# Population at Year-end (10000 persons)                                                    0.389202
# Natural growth rate (‰)                                                                   0.175029
# Number of employees at the end of the year (10,...                                        0.444348
# Number of the registered unemployed at the end ...                                        0.329139
# Average annual salary per urban employee ( Yuan)                                          0.214564
# Number of average employees on site (10,000 Yuan)                                         0.469755
# Population density (person / square kilometer)                                            1.000000
# Per Capita GDP(yuan)                                                                      0.235049
# Secondary industry as percentage to GDP                                                   0.190872
# Service Sector as Percentage to GRP                                                       0.106469
# Total retail sales of social consumer goods (10...                                        0.492881
# Government expenditure on Science (10,000 yuan)                                           0.436301
# Government expenditure on Education (10,000 yuan)                                         0.426389
# Number of secondary schools                                                               0.391801
# Number of theaters                                                                        0.197616
# Collections of public libraries (100 people)                                              0.310982
# Number of employees joining urban basic medical...                                        0.435532
# Persons covered of unemployment insurance                                                 0.450421
# Population (registered residence population) at...                                        0.402260
# Number of male population (registered residence...                                        0.363332
# Number of female population (registered residen...                                        0.291662
#
#                                                     Per Capita GDP(yuan)  \
# Population at Year-end (10000 persons)                         -0.003051
# Natural growth rate (‰)                                        -0.089131
# Number of employees at the end of the year (10,...              0.441006
# Number of the registered unemployed at the end ...              0.338773
# Average annual salary per urban employee ( Yuan)                0.635403
# Number of average employees on site (10,000 Yuan)               0.487550
# Population density (person / square kilometer)                  0.235049
# Per Capita GDP(yuan)                                            1.000000
# Secondary industry as percentage to GDP                         0.197039
# Service Sector as Percentage to GRP                             0.348123
# Total retail sales of social consumer goods (10...              0.539811
# Government expenditure on Science (10,000 yuan)                 0.435895
# Government expenditure on Education (10,000 yuan)               0.370298
# Number of secondary schools                                    -0.044669
# Number of theaters                                              0.358561
# Collections of public libraries (100 people)                    0.629334
# Number of employees joining urban basic medical...              0.458176
# Persons covered of unemployment insurance                       0.492625
# Population (registered residence population) at...              0.011744
# Number of male population (registered residence...             -0.032242
# Number of female population (registered residen...              0.055418
#
#                                                     Secondary industry as percentage to GDP  \
# Population at Year-end (10000 persons)                                            -0.034553
# Natural growth rate (‰)                                                            0.101832
# Number of employees at the end of the year (10,...                                -0.141037
# Number of the registered unemployed at the end ...                                -0.105810
# Average annual salary per urban employee ( Yuan)                                  -0.111315
# Number of average employees on site (10,000 Yuan)                                 -0.148353
# Population density (person / square kilometer)                                     0.190872
# Per Capita GDP(yuan)                                                               0.197039
# Secondary industry as percentage to GDP                                            1.000000
# Service Sector as Percentage to GRP                                               -0.668002
# Total retail sales of social consumer goods (10...                                -0.130766
# Government expenditure on Science (10,000 yuan)                                   -0.171207
# Government expenditure on Education (10,000 yuan)                                 -0.171059
# Number of secondary schools                                                       -0.060469
# Number of theaters                                                                -0.139778
# Collections of public libraries (100 people)                                      -0.121942
# Number of employees joining urban basic medical...                                -0.154364
# Persons covered of unemployment insurance                                         -0.179189
# Population (registered residence population) at...                                -0.031244
# Number of male population (registered residence...                                -0.068590
# Number of female population (registered residen...                                -0.071947
#
#                                                     Service Sector as Percentage to GRP  \
# Population at Year-end (10000 persons)                                         0.108986
# Natural growth rate (‰)                                                       -0.018209
# Number of employees at the end of the year (10,...                             0.462858
# Number of the registered unemployed at the end ...                             0.342014
# Average annual salary per urban employee ( Yuan)                               0.559988
# Number of average employees on site (10,000 Yuan)                              0.497597
# Population density (person / square kilometer)                                 0.106469
# Per Capita GDP(yuan)                                                           0.348123
# Secondary industry as percentage to GDP                                       -0.668002
# Service Sector as Percentage to GRP                                            1.000000
# Total retail sales of social consumer goods (10...                             0.499315
# Government expenditure on Science (10,000 yuan)                                0.446191
# Government expenditure on Education (10,000 yuan)                              0.438602
# Number of secondary schools                                                    0.150424
# Number of theaters                                                             0.361442
# Collections of public libraries (100 people)                                   0.508692
# Number of employees joining urban basic medical...                             0.480598
# Persons covered of unemployment insurance                                      0.521506
# Population (registered residence population) at...                             0.114485
# Number of male population (registered residence...                             0.124954
# Number of female population (registered residen...                             0.202076
#
#                                                     ...  \
# Population at Year-end (10000 persons)              ...
# Natural growth rate (‰)                             ...
# Number of employees at the end of the year (10,...  ...
# Number of the registered unemployed at the end ...  ...
# Average annual salary per urban employee ( Yuan)    ...
# Number of average employees on site (10,000 Yuan)   ...
# Population density (person / square kilometer)      ...
# Per Capita GDP(yuan)                                ...
# Secondary industry as percentage to GDP             ...
# Service Sector as Percentage to GRP                 ...
# Total retail sales of social consumer goods (10...  ...
# Government expenditure on Science (10,000 yuan)     ...
# Government expenditure on Education (10,000 yuan)   ...
# Number of secondary schools                         ...
# Number of theaters                                  ...
# Collections of public libraries (100 people)        ...
# Number of employees joining urban basic medical...  ...
# Persons covered of unemployment insurance           ...
# Population (registered residence population) at...  ...
# Number of male population (registered residence...  ...
# Number of female population (registered residen...  ...
#
#                                                     Government expenditure on Science (10,000 yuan)  \
# Population at Year-end (10000 persons)                                                     0.393479
# Natural growth rate (‰)                                                                   -0.083202
# Number of employees at the end of the year (10,...                                         0.852956
# Number of the registered unemployed at the end ...                                         0.627196
# Average annual salary per urban employee ( Yuan)                                           0.678109
# Number of average employees on site (10,000 Yuan)                                          0.918524
# Population density (person / square kilometer)                                             0.436301
# Per Capita GDP(yuan)                                                                       0.435895
# Secondary industry as percentage to GDP                                                   -0.171207
# Service Sector as Percentage to GRP                                                        0.446191
# Total retail sales of social consumer goods (10...                                         0.843342
# Government expenditure on Science (10,000 yuan)                                            1.000000
# Government expenditure on Education (10,000 yuan)                                          0.907042
# Number of secondary schools                                                                0.463066
# Number of theaters                                                                         0.754657
# Collections of public libraries (100 people)                                               0.686379
# Number of employees joining urban basic medical...                                         0.863062
# Persons covered of unemployment insurance                                                  0.922755
# Population (registered residence population) at...                                         0.397851
# Number of male population (registered residence...                                         0.414496
# Number of female population (registered residen...                                         0.420184
#
#                                                     Government expenditure on Education (10,000 yuan)  \
# Population at Year-end (10000 persons)                                                       0.691046
# Natural growth rate (‰)                                                                     -0.005596
# Number of employees at the end of the year (10,...                                           0.933627
# Number of the registered unemployed at the end ...                                           0.702179
# Average annual salary per urban employee ( Yuan)                                             0.647610
# Number of average employees on site (10,000 Yuan)                                            0.949495
# Population density (person / square kilometer)                                               0.426389
# Per Capita GDP(yuan)                                                                         0.370298
# Secondary industry as percentage to GDP                                                     -0.171059
# Service Sector as Percentage to GRP                                                          0.438602
# Total retail sales of social consumer goods (10...                                           0.912809
# Government expenditure on Science (10,000 yuan)                                              0.907042
# Government expenditure on Education (10,000 yuan)                                            1.000000
# Number of secondary schools                                                                  0.709166
# Number of theaters                                                                           0.713142
# Collections of public libraries (100 people)                                                 0.599770
# Number of employees joining urban basic medical...                                           0.912444
# Persons covered of unemployment insurance                                                    0.924163
# Population (registered residence population) at...                                           0.689698
# Number of male population (registered residence...                                           0.640341
# Number of female population (registered residen...                                           0.737104
#
#                                                     Number of secondary schools  \
# Population at Year-end (10000 persons)                                 0.925888
# Natural growth rate (‰)                                                0.105335
# Number of employees at the end of the year (10,...                     0.665810
# Number of the registered unemployed at the end ...                     0.603625
# Average annual salary per urban employee ( Yuan)                       0.213495
# Number of average employees on site (10,000 Yuan)                      0.612800
# Population density (person / square kilometer)                         0.391801
# Per Capita GDP(yuan)                                                  -0.044669
# Secondary industry as percentage to GDP                               -0.060469
# Service Sector as Percentage to GRP                                    0.150424
# Total retail sales of social consumer goods (10...                     0.640863
# Government expenditure on Science (10,000 yuan)                        0.463066
# Government expenditure on Education (10,000 yuan)                      0.709166
# Number of secondary schools                                            1.000000
# Number of theaters                                                     0.373342
# Collections of public libraries (100 people)                           0.173787
# Number of employees joining urban basic medical...                     0.593738
# Persons covered of unemployment insurance                              0.535998
# Population (registered residence population) at...                     0.921667
# Number of male population (registered residence...                     0.905997
# Number of female population (registered residen...                     0.913002
#
#                                                     Number of theaters  \
# Population at Year-end (10000 persons)                        0.333668
# Natural growth rate (‰)                                      -0.059590
# Number of employees at the end of the year (10,...            0.673397
# Number of the registered unemployed at the end ...            0.405189
# Average annual salary per urban employee ( Yuan)              0.541988
# Number of average employees on site (10,000 Yuan)             0.756170
# Population density (person / square kilometer)                0.197616
# Per Capita GDP(yuan)                                          0.358561
# Secondary industry as percentage to GDP                      -0.139778
# Service Sector as Percentage to GRP                           0.361442
# Total retail sales of social consumer goods (10...            0.701053
# Government expenditure on Science (10,000 yuan)               0.754657
# Government expenditure on Education (10,000 yuan)             0.713142
# Number of secondary schools                                   0.373342
# Number of theaters                                            1.000000
# Collections of public libraries (100 people)                  0.516869
# Number of employees joining urban basic medical...            0.681381
# Persons covered of unemployment insurance                     0.753130
# Population (registered residence population) at...            0.330836
# Number of male population (registered residence...            0.448682
# Number of female population (registered residen...            0.352287
#
#                                                     Collections of public libraries (100 people)  \
# Population at Year-end (10000 persons)                                                  0.100106
# Natural growth rate (‰)                                                                -0.045796
# Number of employees at the end of the year (10,...                                      0.642923
# Number of the registered unemployed at the end ...                                      0.414871
# Average annual salary per urban employee ( Yuan)                                        0.679617
# Number of average employees on site (10,000 Yuan)                                       0.705856
# Population density (person / square kilometer)                                          0.310982
# Per Capita GDP(yuan)                                                                    0.629334
# Secondary industry as percentage to GDP                                                -0.121942
# Service Sector as Percentage to GRP                                                     0.508692
# Total retail sales of social consumer goods (10...                                      0.653051
# Government expenditure on Science (10,000 yuan)                                         0.686379
# Government expenditure on Education (10,000 yuan)                                       0.599770
# Number of secondary schools                                                             0.173787
# Number of theaters                                                                      0.516869
# Collections of public libraries (100 people)                                            1.000000
# Number of employees joining urban basic medical...                                      0.701853
# Persons covered of unemployment insurance                                               0.747016
# Population (registered residence population) at...                                      0.108059
# Number of male population (registered residence...                                      0.123040
# Number of female population (registered residen...                                      0.118407
#
#                                                     Number of employees joining urban basic medical care system  \
# Population at Year-end (10000 persons)                                                       0.589624
# Natural growth rate (‰)                                                                     -0.112778
# Number of employees at the end of the year (10,...                                           0.933823
# Number of the registered unemployed at the end ...                                           0.708512
# Average annual salary per urban employee ( Yuan)                                             0.641831
# Number of average employees on site (10,000 Yuan)                                            0.939653
# Population density (person / square kilometer)                                               0.435532
# Per Capita GDP(yuan)                                                                         0.458176
# Secondary industry as percentage to GDP                                                     -0.154364
# Service Sector as Percentage to GRP                                                          0.480598
# Total retail sales of social consumer goods (10...                                           0.925775
# Government expenditure on Science (10,000 yuan)                                              0.863062
# Government expenditure on Education (10,000 yuan)                                            0.912444
# Number of secondary schools                                                                  0.593738
# Number of theaters                                                                           0.681381
# Collections of public libraries (100 people)                                                 0.701853
# Number of employees joining urban basic medical...                                           1.000000
# Persons covered of unemployment insurance                                                    0.940605
# Population (registered residence population) at...                                           0.596183
# Number of male population (registered residence...                                           0.504975
# Number of female population (registered residen...                                           0.656401
#
#                                                     Persons covered of unemployment insurance  \
# Population at Year-end (10000 persons)                                               0.499847
# Natural growth rate (‰)                                                             -0.070395
# Number of employees at the end of the year (10,...                                   0.946259
# Number of the registered unemployed at the end ...                                   0.637713
# Average annual salary per urban employee ( Yuan)                                     0.680536
# Number of average employees on site (10,000 Yuan)                                    0.976690
# Population density (person / square kilometer)                                       0.450421
# Per Capita GDP(yuan)                                                                 0.492625
# Secondary industry as percentage to GDP                                             -0.179189
# Service Sector as Percentage to GRP                                                  0.521506
# Total retail sales of social consumer goods (10...                                   0.917885
# Government expenditure on Science (10,000 yuan)                                      0.922755
# Government expenditure on Education (10,000 yuan)                                    0.924163
# Number of secondary schools                                                          0.535998
# Number of theaters                                                                   0.753130
# Collections of public libraries (100 people)                                         0.747016
# Number of employees joining urban basic medical...                                   0.940605
# Persons covered of unemployment insurance                                            1.000000
# Population (registered residence population) at...                                   0.505678
# Number of male population (registered residence...                                   0.438574
# Number of female population (registered residen...                                   0.534776
#
#                                                     Population (registered residence population) at the end of the year (10,000)  \
# Population at Year-end (10000 persons)                                                       0.995504
# Natural growth rate (‰)                                                                      0.110815
# Number of employees at the end of the year (10,...                                           0.669269
# Number of the registered unemployed at the end ...                                           0.565435
# Average annual salary per urban employee ( Yuan)                                             0.179959
# Number of average employees on site (10,000 Yuan)                                            0.589766
# Population density (person / square kilometer)                                               0.402260
# Per Capita GDP(yuan)                                                                         0.011744
# Secondary industry as percentage to GDP                                                     -0.031244
# Service Sector as Percentage to GRP                                                          0.114485
# Total retail sales of social consumer goods (10...                                           0.651304
# Government expenditure on Science (10,000 yuan)                                              0.397851
# Government expenditure on Education (10,000 yuan)                                            0.689698
# Number of secondary schools                                                                  0.921667
# Number of theaters                                                                           0.330836
# Collections of public libraries (100 people)                                                 0.108059
# Number of employees joining urban basic medical...                                           0.596183
# Persons covered of unemployment insurance                                                    0.505678
# Population (registered residence population) at...                                           1.000000
# Number of male population (registered residence...                                           0.996498
# Number of female population (registered residen...                                           0.997499
#
#                                                     Number of male population (registered residence population) at the end of the year (10,000)  \
# Population at Year-end (10000 persons)                                                       0.987769
# Natural growth rate (‰)                                                                      0.203345
# Number of employees at the end of the year (10,...                                           0.565574
# Number of the registered unemployed at the end ...                                           0.501138
# Average annual salary per urban employee ( Yuan)                                             0.224353
# Number of average employees on site (10,000 Yuan)                                            0.526562
# Population density (person / square kilometer)                                               0.363332
# Per Capita GDP(yuan)                                                                        -0.032242
# Secondary industry as percentage to GDP                                                     -0.068590
# Service Sector as Percentage to GRP                                                          0.124954
# Total retail sales of social consumer goods (10...                                           0.628980
# Government expenditure on Science (10,000 yuan)                                              0.414496
# Government expenditure on Education (10,000 yuan)                                            0.640341
# Number of secondary schools                                                                  0.905997
# Number of theaters                                                                           0.448682
# Collections of public libraries (100 people)                                                 0.123040
# Number of employees joining urban basic medical...                                           0.504975
# Persons covered of unemployment insurance                                                    0.438574
# Population (registered residence population) at...                                           0.996498
# Number of male population (registered residence...                                           1.000000
# Number of female population (registered residen...                                           0.996123
#
#                                                     Number of female population (registered residence population) at the end of the year (10,000)
# Population at Year-end (10000 persons)                                                       0.991756
# Natural growth rate (‰)                                                                      0.083318
# Number of employees at the end of the year (10,...                                           0.716288
# Number of the registered unemployed at the end ...                                           0.560281
# Average annual salary per urban employee ( Yuan)                                             0.260412
# Number of average employees on site (10,000 Yuan)                                            0.624974
# Population density (person / square kilometer)                                               0.291662
# Per Capita GDP(yuan)                                                                         0.055418
# Secondary industry as percentage to GDP                                                     -0.071947
# Service Sector as Percentage to GRP                                                          0.202076
# Total retail sales of social consumer goods (10...                                           0.689590
# Government expenditure on Science (10,000 yuan)                                              0.420184
# Government expenditure on Education (10,000 yuan)                                            0.737104
# Number of secondary schools                                                                  0.913002
# Number of theaters                                                                           0.352287
# Collections of public libraries (100 people)                                                 0.118407
# Number of employees joining urban basic medical...                                           0.656401
# Persons covered of unemployment insurance                                                    0.534776
# Population (registered residence population) at...                                           0.997499
# Number of male population (registered residence...                                           0.996123
# Number of female population (registered residen...                                           1.000000
#
# [21 rows x 21 columns]

# %%
sns.set_theme(style="white")

corr = df.iloc[:, 3:-1].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
small = df.dropna().drop(["City", "location_ENG", "province"], axis=1)
small
# Out:
#             number of cases  Population at Year-end (10000 persons)  \
# Unnamed: 0
# 0                         0                              608.008000
# 1                         0                              262.801714
# 2                         1                               81.662000
# 3                         1                              286.424000
# 5                         1                              192.944000
# ...                     ...                                     ...
# 261                      27                              594.772000
# 263                      37                              740.670000
# 265                      40                              878.518000
# 267                      46                              732.304000
# 269                      89                             1355.320000
#
#             Natural growth rate (‰)  \
# Unnamed: 0
# 0                          9.540000
# 1                          3.688571
# 2                         -2.048000
# 3                         13.562000
# 5                          9.894000
# ...                             ...
# 261                        0.886000
# 263                        6.198000
# 265                       11.752000
# 267                        9.740000
# 269                        3.542000
#
#             Number of employees at the end of the year (10,000 Yuan)  \
# Unnamed: 0
# 0                                                   67.622800
# 1                                                   31.986631
# 2                                                   10.089300
# 3                                                   24.403080
# 5                                                   42.442100
# ...                                                       ...
# 261                                                107.729520
# 263                                                287.669300
# 265                                                329.952140
# 267                                                154.315000
# 269                                                791.377080
#
#             Number of the registered unemployed at the end of year  \
# Unnamed: 0
# 0                                                31644.066667
# 1                                                28642.000000
# 2                                                 8840.800000
# 3                                                10091.200000
# 5                                                11774.800000
# ...                                                       ...
# 261                                              83017.000000
# 263                                              38906.600000
# 265                                             224317.000000
# 267                                             176493.600000
# 269                                              88137.200000
#
#             Average annual salary per urban employee ( Yuan)  \
# Unnamed: 0
# 0                                               62658.793333
# 1                                               61967.695714
# 2                                               48290.960000
# 3                                               65480.386000
# 5                                               73561.942000
# ...                                                      ...
# 261                                             75247.886000
# 263                                             87834.288000
# 265                                             90992.826000
# 267                                             72602.884000
# 269                                            124811.882000
#
#             Number of average employees on site (10,000 Yuan)  \
# Unnamed: 0
# 0                                                   58.364833
# 1                                                   31.212000
# 2                                                    9.762000
# 3                                                   21.344000
# 5                                                   40.810000
# ...                                                       ...
# 261                                                101.558000
# 263                                                264.614000
# 265                                                314.980000
# 267                                                134.558000
# 269                                                737.550000
#
#             Population density (person / square kilometer)  \
# Unnamed: 0
# 0                                               257.246667
# 1                                                53.709286
# 2                                               137.615000
# 3                                               123.670000
# 5                                               230.550000
# ...                                                    ...
# 261                                             472.515000
# 263                                             433.765000
# 265                                            1140.990000
# 267                                             625.080000
# 269                                             816.035000
#
#             Per Capita GDP(yuan)  Secondary industry as percentage to GDP  \
# Unnamed: 0
# 0                   36500.600000                                44.026667
# 1                   90488.035714                                44.191786
# 2                   27462.000000                                38.465000
# 3                   74308.750000                                51.567500
# 5                  172369.600000                                63.905000
# ...                          ...                                      ...
# 261                105534.800000                                43.932500
# 263                123124.400000                                37.730000
# 265                142553.600000                                30.450000
# 267                 81371.000000                                51.182500
# 269                116225.250000                                19.735000
#
#             ...  Government expenditure on Science (10,000 yuan)  \
# Unnamed: 0  ...
# 0           ...                                     6.183747e+04
# 1           ...                                     2.560757e+04
# 2           ...                                     1.811600e+03
# 3           ...                                     4.177380e+04
# 5           ...                                     4.421380e+04
# ...         ...                                              ...
# 261         ...                                     2.594102e+05
# 263         ...                                     8.160176e+05
# 265         ...                                     1.185734e+06
# 267         ...                                     6.591710e+05
# 269         ...                                     3.287752e+06
#
#             Government expenditure on Education (10,000 yuan)  \
# Unnamed: 0
# 0                                                9.727978e+05
# 1                                                5.221551e+05
# 2                                                8.377680e+04
# 3                                                5.206828e+05
# 5                                                5.033196e+05
# ...                                                       ...
# 261                                              1.087218e+06
# 263                                              2.507756e+06
# 265                                              3.366507e+06
# 267                                              1.304910e+06
# 269                                              8.950368e+06
#
#             Number of secondary schools  Number of theaters  \
# Unnamed: 0
# 0                            259.000000           23.000000
# 1                            106.142857           14.142857
# 2                             45.000000            3.000000
# 3                            156.400000           20.000000
# 5                             95.600000           20.000000
# ...                                 ...                 ...
# 261                          289.400000            6.000000
# 263                          327.800000           78.000000
# 265                          513.800000           53.000000
# 267                          356.600000           49.000000
# 269                          645.600000          251.000000
#
#             Collections of public libraries (100 people)  \
# Unnamed: 0
# 0                                              30.530000
# 1                                              72.278571
# 2                                              27.700000
# 3                                             169.860000
# 5                                             113.150000
# ...                                                  ...
# 261                                           265.935000
# 263                                           267.400000
# 265                                           245.045000
# 267                                            66.160000
# 269                                           430.920000
#
#             Number of employees joining urban basic medical care system  \
# Unnamed: 0
# 0                                                9.843509e+05
# 1                                                6.067097e+05
# 2                                                2.080992e+05
# 3                                                4.722470e+05
# 5                                                9.506680e+05
# ...                                                       ...
# 261                                              4.149643e+06
# 263                                              6.165799e+06
# 265                                              7.470691e+06
# 267                                              2.150477e+06
# 269                                              1.559115e+07
#
#             Persons covered of unemployment insurance  \
# Unnamed: 0
# 0                                        4.520328e+05
# 1                                        2.791685e+05
# 2                                        9.940800e+04
# 3                                        2.930834e+05
# 5                                        2.836768e+05
# ...                                               ...
# 261                                      1.484521e+06
# 263                                      3.861586e+06
# 265                                      5.134895e+06
# 267                                      1.336439e+06
# 269                                      1.133703e+07
#
#             Population (registered residence population) at the end of the year (10,000)  \
# Unnamed: 0
# 0                                                  421.667714
# 1                                                  262.895000
# 2                                                   81.522000
# 3                                                  286.432000
# 5                                                  192.880000
# ...                                                       ...
# 261                                                594.794000
# 263                                                740.666000
# 265                                                878.430000
# 267                                                732.248000
# 269                                               1347.150967
#
#             Number of male population (registered residence population) at the end of the year (10,000)  \
# Unnamed: 0
# 0                                                  218.546626
# 1                                                  145.182474
# 2                                                   41.584000
# 3                                                  149.690000
# 5                                                   96.264000
# ...                                                       ...
# 261                                                295.560000
# 263                                                368.673840
# 265                                                440.542000
# 267                                                377.822000
# 269                                                674.381500
#
#             Number of female population (registered residence population) at the end of the year (10,000)
# Unnamed: 0
# 0                                                  203.119057
# 1                                                  135.336669
# 2                                                   39.971780
# 3                                                  136.570000
# 5                                                   96.580000
# ...                                                       ...
# 261                                                299.168000
# 263                                                371.983300
# 265                                                437.990000
# 267                                                354.396000
# 269                                                672.769467
#
# [188 rows x 22 columns]

# %%
# Separating out the features
x = small.iloc[:, 1:].values
# Separating out the target
y = small.loc[:, "number of cases"].values
# Standardizing the features
x = preprocessing.StandardScaler().fit_transform(x)
x
# Out:
# array([[ 0.64214728,  0.52556877,  0.09014485, ..., -0.08210452,
#         -0.05502094, -0.08913882],
#        [-0.76457135, -0.53897174, -0.35499171, ..., -0.73606777,
#         -0.65344339, -0.66728132],
#        [-1.50271727, -1.58261649, -0.62851446, ..., -1.48311854,
#         -1.49848353, -1.48068575],
#        ...,
#        [ 1.7444779 ,  0.92799419,  3.36693877, ...,  1.79923733,
#          1.75576829,  1.91416732],
#        [ 1.14865457,  0.56195443,  1.17302972, ...,  1.19713352,
#          1.24416889,  1.2011614 ],
#        [ 3.68745022, -0.56563724,  9.13066476, ...,  3.72983536,
#          3.66316861,  3.91669321]])

# %%
pca = PCA(n_components=len(small.columns)-1)
x_reduced = pca.fit_transform(x)

# %%
y = pca.explained_variance_ratio_
plot.plt(x=)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)

ax.scatter(x_reduced[:, 0], x_reduced[:, 1], c=y,
           cmap=plt.cm.Set1, edgecolor='k', s=40)
ax.grid()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge

# X_train,X_test,y_train,y_test=train_test_split(newX,newY,test_size=0.3,random_state=3)

X = se_cnt.iloc[:, :-1]
Y = se_cnt.Count

lr = LinearRegression()
lr.fit(X, Y)

rr = Ridge(alpha=0.01) 
# higher the alpha value, more restriction on the coefficients; low alpha > more generalization,
# in this case linear and ridge regression resembles
rr.fit(X, y)
rr100 = Ridge(alpha=100) #  comparison with alpha value
rr100.fit(X, y)
train_score=lr.score(X, Y)
#test_score=lr.score(X_test, y_test)

Ridge_train_score = rr.score(X, Y)
#Ridge_test_score = rr.score(X_test, y_test)

Ridge_train_score100 = rr100.score(X,Y)
#Ridge_test_score100 = rr100.score(X_test, y_test)

plt.plot(rr.coef_,alpha=0.7,linestyle='none',marker='*',markersize=5,color='red',label=r'Ridge; $\alpha = 0.01$',zorder=7) 
plt.plot(rr100.coef_,alpha=0.5,linestyle='none',marker='d',markersize=6,color='blue',label=r'Ridge; $\alpha = 100$') 
plt.plot(lr.coef_,alpha=0.4,linestyle='none',marker='o',markersize=7,color='green',label='Linear Regression')
plt.xlabel('Coefficient Index',fontsize=16)
plt.ylabel('Coefficient Magnitude',fontsize=16)
plt.legend(fontsize=13,loc=4)
plt.show()

# %%
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

X = se_cnt.iloc[:, :-1]
Y = se_cnt.Count

# X_train,X_test,y_train,y_test=train_test_split(X,Y, test_size=0.3, random_state=31)
lasso = Lasso()
lasso.fit(X, Y)
train_score=lasso.score(X, Y)
# test_score=lasso.score(X_test,y_test)
coeff_used = np.sum(lasso.coef_!=0)
print("training score:", train_score)
# print "test score: ", test_score
print("number of features used: ", coeff_used)

lasso001 = Lasso(alpha=0.01, max_iter=10e5)
lasso001.fit(X, Y)
train_score001=lasso001.score(X, Y)
# test_score001=lasso001.score(X_test,y_test)
coeff_used001 = np.sum(lasso001.coef_!=0)
print("training score for alpha=0.01:", train_score001)
# print "test score for alpha =0.01: ", test_score001
print("number of features used: for alpha =0.01:", coeff_used001)

lasso00001 = Lasso(alpha=0.0001, max_iter=10e5)
lasso00001.fit(X, Y)
train_score00001=lasso00001.score(X, Y)
# test_score00001=lasso00001.score(X_test,y_test)
coeff_used00001 = np.sum(lasso00001.coef_!=0)
print("training score for alpha=0.0001:", train_score00001)
# print "test score for alpha =0.0001: ", test_score00001
print("number of features used: for alpha =0.0001:", coeff_used00001)


lr = LinearRegression()
lr.fit(X, Y)
lr_train_score=lr.score(X, Y)
# lr_test_score=lr.score(X_test,y_test)
print("LR training score:", lr_train_score)
# print("LR test score: ", lr_test_score)
plt.subplot(1,2,1)
plt.plot(lasso.coef_,alpha=0.7,linestyle='none',marker='*',markersize=5,color='red',label=r'Lasso; $\alpha = 1$',zorder=7) # alpha here is for transparency
plt.plot(lasso001.coef_,alpha=0.5,linestyle='none',marker='d',markersize=6,color='blue',label=r'Lasso; $\alpha = 0.01$') # alpha here is for transparency

plt.xlabel('Coefficient Index',fontsize=16)
plt.ylabel('Coefficient Magnitude',fontsize=16)
plt.legend(fontsize=13,loc=4)
plt.subplot(1,2,2)
plt.plot(lasso.coef_,alpha=0.7,linestyle='none',marker='*',markersize=5,color='red',label=r'Lasso; $\alpha = 1$',zorder=7) # alpha here is for transparency
plt.plot(lasso001.coef_,alpha=0.5,linestyle='none',marker='d',markersize=6,color='blue',label=r'Lasso; $\alpha = 0.01$') # alpha here is for transparency
plt.plot(lasso00001.coef_,alpha=0.8,linestyle='none',marker='v',markersize=6,color='black',label=r'Lasso; $\alpha = 0.00001$') # alpha here is for transparency
plt.plot(lr.coef_,alpha=0.7,linestyle='none',marker='o',markersize=5,color='green',label='Linear Regression',zorder=2)
plt.xlabel('Coefficient Index',fontsize=16)
plt.ylabel('Coefficient Magnitude',fontsize=16)
plt.legend(fontsize=13,loc=4)
plt.tight_layout()
plt.show()
# Out:
# training score: 0.9284188092503025
# number of features used:  99
# training score for alpha=0.01: 0.9306610745088248
# number of features used: for alpha =0.01: 96
# training score for alpha=0.0001: 0.9306610971564705
# number of features used: for alpha =0.0001: 121
# LR training score: 0.9306610988370682

# %%
lr.coef_
# Out:
# array([ 7.68520282e-06,  6.70733471e-06,  9.90280063e-06,  1.27561537e-05,
#        -1.79353146e-04,  1.65236851e-06, -3.48045184e-04,  6.21059454e-06,
#        -1.32487428e-05, -1.06627726e-05,  8.98799561e-06,  4.18574436e-04,
#        -1.74848538e-04, -9.99049350e-08,  1.64653436e-04,  9.95551880e-06,
#         4.79649335e-05,  7.06127474e-06, -9.14949133e-06, -3.48460284e-06,
#        -6.52601526e-07,  1.75631353e-05,  2.45200010e-08,  1.96409760e-06,
#        -1.30032003e-05,  1.10488597e-05,  1.12954386e-05,  3.50927544e-06,
#        -1.17236380e-04,  2.52288012e-06, -2.11197942e-05,  4.47733677e-06,
#         1.12961167e-04,  2.85752639e-05, -1.81089699e-07, -1.60988478e-07,
#         5.13547961e-07, -3.18663068e-06,  5.40767779e-07,  1.72695332e-04,
#         1.01014166e-04, -5.28111043e-05, -8.16511349e-07,  6.15853219e-06,
#        -1.43999808e-05,  4.67629892e-05,  1.43857839e-04, -5.50861175e-05,
#        -4.20884849e-05,  9.13429579e-07,  2.01990202e-06, -7.17018948e-07,
#        -1.19990529e-06, -6.30947565e-08, -3.26028561e-04,  1.32819354e-08,
#         1.28500239e-04, -1.08867652e-03, -4.14188312e-04,  4.17679185e-05,
#         2.64381578e-07,  6.77631935e-05, -1.44748253e-04,  1.59608240e-05,
#         1.70555348e-04, -1.66734989e-06, -8.81381222e-06,  1.04880461e-05,
#        -1.44748253e-04,  1.96348782e-05,  9.69239230e-06, -8.09831577e-05,
#         6.76167112e-05, -3.20085313e-04,  1.17278199e-04, -3.41976881e-05,
#        -8.88559093e-05,  2.34106055e-04, -3.54442561e-04, -4.36229551e-04,
#        -4.08230415e-04, -6.81499045e-04, -4.43605801e-04, -2.58655982e-04,
#        -5.49458275e-05, -8.76818167e-05, -2.06814259e-06, -1.03471595e-05,
#        -1.99602196e-04,  1.02567584e-06, -1.86502614e-07,  2.91054978e-05,
#        -1.60508660e-04,  3.65273723e-04, -4.40669227e-04,  4.31028482e-04,
#        -4.59881224e-04,  4.87997169e-05, -1.76543620e-06, -1.48502922e-06,
#        -8.93542102e-07, -1.11011186e-05,  1.09811990e-05,  3.22162212e-06,
#         4.43589920e-05,  3.72710645e-04, -2.89475358e-04, -5.08149882e-06,
#         1.49711430e-06,  1.17607865e-05, -2.28152304e-06, -1.01443763e-03,
#         5.09139785e-04, -3.11742372e-04, -5.05149252e-05, -3.42787713e-04,
#        -4.03614139e-04, -2.34917424e-04,  4.04663915e-05, -6.80664388e-07,
#        -2.59515920e-05,  3.77020457e-05,  4.79776732e-06, -7.17955209e-06,
#         2.12395889e-05,  1.97471553e-06, -6.12095493e-05,  5.64803074e-05,
#        -7.34977392e-05])
